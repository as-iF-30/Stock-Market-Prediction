# %%
from cran import Stocker

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from datetime import datetime
intial = datetime(2018, 3, 27 , 0, 0, 0)
current_days = datetime.now() - intial
n = current_days.days

# %% [markdown]
# # IT industries

# %% [markdown]
# MICROSOFT
# <img src="MSFt.png" width="100" height="100">

# %%
microsoft = Stocker('MSFT')
# Out:
# MSFT Stocker Initialized. Data covers 1986-03-13 00:00:00 to 2018-03-27 00:00:00.

# %%
model, future = microsoft.create_prophet_model(days=n)
# Out:
# Predicted Price on 2019-09-21 00:00:00 = $135.88

# %%
model.plot_components(future)
plt.show()

# %% [markdown]
# # Changepoint Prior Scale Selection

# %% [markdown]
# Changepoints represent where a time series goes from increasing to decreasing or from increasing slowly to increasingly rapidly. They occur at the places with the greatest change in the rate of the time series.
#
# The changepoint prior scale represents the amount of weight given to the changepoints in the model. This can be used to control overfitting vs underfitting. A higher prior will create a model with more flexibility and more emphasis on the changepoints. This can lead to overfitting because the model will closely follow the training data. Lowering the prior decreases the model flexibility which can cause the opposite problem underfitting. This occurs when our model does not follow the training data closely enough and fails to learn the underlying relationships.

# %%
microsoft.changepoint_prior_analysis(changepoint_priors=[0.001, 0.05, 0.1, 0.2])

# %%
microsoft.evaluate_prediction(start_date = '2008-01-03', end_date = '2009-01-05', nshares=500)
# Out:
# C:\Users\asus\cran.py:624: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# You played the stock market in MSFT from 2008-01-03 00:00:00 to 2009-01-05 00:00:00 with 500 shares.
#
# When the model predicted an increase, the price increased 40.41% of the time.
# When the model predicted a  decrease, the price decreased  56.19% of the time.
#
# The total profit using the Prophet model = $-4300.52.
# The Buy and Hold strategy profit =         $-6070.46.
#
# Thanks for playing the stock market!

# %% [markdown]
# APPLE
# <img src="AAPL.png" width="400" height="100">

# %%
apple = Stocker('AAPL')
# Out:
# AAPL Stocker Initialized. Data covers 1980-12-12 00:00:00 to 2018-03-27 00:00:00.

# %%
model, future = apple.create_prophet_model(days=n)
# Out:
# Predicted Price on 2019-09-21 00:00:00 = $230.08

# %% [markdown]
# # Auto Corps.

# %% [markdown]
# TRACTOR SUPPLY COMPANY
# <img src="TSCO.png" width="400" height="200">

# %%
tractor_supply_company = Stocker('TSCO')
# Out:
# TSCO Stocker Initialized. Data covers 1994-02-18 00:00:00 to 2018-03-27 00:00:00.

# %%
model, future = tractor_supply_company.create_prophet_model(days = n)
# Out:
# Predicted Price on 2019-09-21 00:00:00 = $91.09

# %% [markdown]
# Ford Motor Company
# <img src="F.png" width="400" height="100">

# %%
ford = Stocker('F')
# Out:
# F Stocker Initialized. Data covers 1972-06-01 00:00:00 to 2018-03-27 00:00:00.

# %%
model, future = ford.create_prophet_model(days=n)
# Out:
# Predicted Price on 2019-09-21 00:00:00 = $9.91

# %% [markdown]
# # Food

# %% [markdown]
# B&G Foods, inc.
# <img src="BGS.jpg" width="420" height="100">

# %%
bg = Stocker('BGS')
# Out:
# BGS Stocker Initialized. Data covers 2007-05-23 00:00:00 to 2018-03-27 00:00:00.

# %%
model, future = bg.create_prophet_model(days=n)
# Out:
# Predicted Price on 2019-09-21 00:00:00 = $19.90

# %% [markdown]
# Kellogg Company
# <img src="K.png" width="300" height="100">

# %%
k = Stocker('K')
# Out:
# K Stocker Initialized. Data covers 1984-12-17 00:00:00 to 2018-03-27 00:00:00.

# %%
model, future = k.create_prophet_model(days=n)
# Out:
# Predicted Price on 2019-09-21 00:00:00 = $62.14

# %% [markdown]
# # Bank

# %% [markdown]
# Bank Of Hawaii Corporation
# <img src="BOH.png" width="200" height="100">

# %%
hawaii = Stocker('BOH')
# Out:
# BOH Stocker Initialized. Data covers 1984-09-07 00:00:00 to 2018-03-27 00:00:00.

# %%
model, future = hawaii.create_prophet_model(days=n)
# Out:
# Predicted Price on 2019-09-21 00:00:00 = $86.98

# %%
#FNB
#CUBI
#USB

# %% [markdown]
# F.N.B. Corporation
# <img src="FNB.jpg" width="400" height="100">

# %%
fnb = Stocker('FNB')
# Out:
# FNB Stocker Initialized. Data covers 1993-03-04 00:00:00 to 2018-03-27 00:00:00.

# %%
model, future = fnb.create_prophet_model(days=n)
# Out:
# Predicted Price on 2019-09-21 00:00:00 = $12.81

# %% [markdown]
# # Fashion

# %% [markdown]
# Genesco, Inc.
# <img src="GCO.jpg" width="300" height="100">

# %%
genesco = Stocker('GCO')
# Out:
# GCO Stocker Initialized. Data covers 1985-07-01 00:00:00 to 2018-03-27 00:00:00.

# %%
model, future = genesco.create_prophet_model(days=n)
# Out:
# Predicted Price on 2019-09-26 00:00:00 = $39.24

# %% [markdown]
# Chico's FAS, Inc.
# <img src="CHS.png" width="400" height="150">

# %%
chicos_fas = Stocker('CHS')
# Out:
# CHS Stocker Initialized. Data covers 1993-03-24 00:00:00 to 2018-03-27 00:00:00.

# %%
model, future = chicos_fas.create_prophet_model(days=n)
# Out:
# Predicted Price on 2019-09-26 00:00:00 = $4.08
